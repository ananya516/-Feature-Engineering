# %%
1. What is a Parameter?

A parameter is a value that describes a characteristic of a population (e.g., population mean or standard deviation).
It is usually fixed and unknown, unlike statistics which are derived from samples.

2. What is Correlation?

Correlation measures the strength and direction of a linear relationship between two variables.
It ranges from -1 (perfect negative correlation) to +1 (perfect positive correlation), with 0 meaning no correlation.

3. What Does Negative Correlation Mean?

Negative correlation means that as one variable increases, the other decreases.
Example: As the number of hours watching TV increases, academic performance may decrease.


4. Define Machine Learning

Machine Learning is a subset of AI that enables systems to learn patterns from data and make predictions or decisions without being explicitly programmed.

5. What Are the Main Components in Machine Learning?

Dataset: Input data for learning.
Features: Variables used to make predictions.
Model: Algorithm that learns patterns from data.
Loss Function: Measures the error in predictions.
Optimizer: Improves the model by minimizing the loss function.
Evaluation Metric: Assesses the model’s performance.

6. How Does Loss Value Help in Determining if the Model is Good or Not?

Loss value quantifies how far off the model’s predictions are from actual values.
A lower loss value means better model performance; a high loss indicates poor prediction.


7. What Are Continuous and Categorical Variables?

Continuous Variables: Can take any numerical value (e.g., height, salary).
Categorical Variables: Represent categories or labels (e.g., gender, country).

8. How Do We Handle Categorical Variables in Machine Learning?

Convert them into numeric form using encoding techniques.

9. Common Techniques to Handle Categorical Variables

Label Encoding: Assigns a unique integer to each category.
One-Hot Encoding: Converts categories into binary vectors.


10. What Do You Mean by Training and Testing a Dataset?

Training Set: Used to teach the model.
Testing Set: Used to evaluate how well the model performs on unseen data.

11. What is sklearn.preprocessing?

A module in Scikit-learn that provides functions for preprocessing data like scaling, encoding, normalization, etc.

12. What is a Test Set?

A portion of the dataset that is used only after training to evaluate model performance.

13. How Do We Split Data for Model Fitting in Python?

Use train_test_split() from sklearn.model_selection.

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
14. How Do You Approach a Machine Learning Problem?
Understand the problem and dataset.

Perform EDA (exploratory data analysis).

Preprocess the data.

Choose a model.

Train the model.

Evaluate performance.

Tune hyperparameters if needed.

15. Why Do We Perform EDA Before Fitting a Model?

EDA helps uncover patterns, missing values, outliers, and relationships between variables.
It informs data preprocessing and model selection.


16. How to Find Correlation Between Variables in Python?

df.corr()  # For Pearson correlation

17. What is Causation?
Causation implies one variable directly affects the other.

18. Difference Between Correlation and Causation (Example)
Correlation: Ice cream sales and drowning deaths are correlated (both increase in summer).

Causation: But ice cream doesn’t cause drowning—weather is a common cause.


19. What is an Optimizer?
An optimizer adjusts the model parameters to minimize the loss function.

20. Types of Optimizers
Gradient Descent: Basic optimizer using gradients to minimize loss.

Stochastic Gradient Descent (SGD): Uses one data point per update.

Adam: Combines momentum and adaptive learning rates for better performance.

RMSProp: Uses moving average of squared gradients for learning rate adjustment.


21. What is sklearn.linear_model?
It provides linear models like LinearRegression, LogisticRegression, etc.

22. What Does model.fit() Do?
Trains the model using the training data.

Arguments: X_train (features), y_train (target).

23. What Does model.predict() Do?
Predicts output for given input data.

Argument: X_test or new data.

24. What is Feature Scaling?
Feature scaling standardizes or normalizes features to ensure they're on the same scale.

It improves model performance, especially for distance-based algorithms.

25. How is Feature Scaling Done in Python?

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

26. Explain Data Encoding

Data encoding converts categorical values into numerical format for model input.
Common techniques: Label Encoding, One-Hot Encoding, Binary Encoding.
